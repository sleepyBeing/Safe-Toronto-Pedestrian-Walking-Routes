# %%
import osmnx as ox
import geopandas as gpd
import numpy as np
import re
import pandas as pd

place = 'Toronto, Canada'

network = ox.graph_from_place(place, network_type='walk')
gdf_nodes, gdf_edges = ox.graph_to_gdfs(network)

gdf_edges.head()
gdf_edges.info()
gdf_edges.crs
gdf_edges.geom_type.value_counts()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 615076 entries, (1497902, 7474494702, 0) to (13414083380, 10039443198, 0)
# Data columns (total 17 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   osmid      615076 non-null  object
#  1   lanes      212106 non-null  object
#  2   name       186858 non-null  object
#  3   highway    615076 non-null  object
#  4   oneway     615076 non-null  bool
#  5   reversed   615076 non-null  object
#  6   length     615076 non-null  float64
#  7   geometry   615076 non-null  geometry
#  8   maxspeed   101854 non-null  object
#  9   bridge     2968 non-null    object
#  10  access     32116 non-null   object
#  11  service    89852 non-null   object
#  12  width      7772 non-null    object
#  13  junction   254 non-null     object
#  14  tunnel     3376 non-null    object
#  15  est_width  112 non-null     object
#  16  area       44 non-null      object
# dtypes: bool(1), float64(1), geometry(1), object(14)
# memory usage: 100.2+ MB
# LineString    615076
# Name: count, dtype: int64
